# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import set_config

# %%
import joblib

# %%
set_config(transform_output="pandas")

# %%
# data and model paths

data_path = "../data/interim/df_without_outliers.csv"

kmeans_path = "../models/mb_kmeans.joblib"
scaler_path = "../models/scaler.joblib"
encoder_path = "../models/encoder.joblib"
model_path = "../models/model.joblib"

# %%
# load the data

df = pd.read_csv(data_path, usecols=["pickup_longitude","pickup_latitude"])

df.shape
# Out:
# (33234199, 2)

# %%
# load the scaler and model

scaler = joblib.load(scaler_path)
kmeans = joblib.load(kmeans_path)

# %%
scaler
# Out:
# StandardScaler()

# %%
kmeans
# Out:
# MiniBatchKMeans(n_clusters=30, n_init=10, random_state=42)

# %%
# scale the input data

df_scaled = scaler.transform(df)

df_scaled.head()
# Out:
#    pickup_longitude  pickup_latitude
# 0         -0.443778        -0.601549
# 1         -0.182839        -0.777271
# 2         -0.285388        -2.626699
# 3         -0.528059        -1.178462
# 4          0.365612         1.111533

# %%
# get the cluster predictions

predictions = kmeans.predict(df_scaled)
# Out:
# c:\Users\himan\anaconda3\envs\demand_prediction\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but MiniBatchKMeans was fitted without feature names
#   warnings.warn(

# %%
# add the predictions to data

df['region'] = predictions

df.head()
# Out:
#    pickup_longitude  pickup_latitude  region
# 0        -73.990372        40.734695       7
# 1        -73.980782        40.729912      26
# 2        -73.984550        40.679565       9
# 3        -73.993469        40.718990      10
# 4        -73.960625        40.781330       8

# %%
# form a region grp

region_grp = df.groupby("region")

# %%
# sample the data from each region

sampled_data = (
    region_grp
    .sample(500, random_state=42)
)

# %%
sampled_data.shape
# Out:
# (15000, 3)

# %%
sampled_data
# Out:
#           pickup_longitude  pickup_latitude  region
# 3269108         -73.961357        40.806641       0
# 31107559        -73.949677        40.801151       0
# 4464996         -73.954544        40.805717       0
# 27828548        -73.960274        40.813190       0
# 9889390         -73.962280        40.805012       0
# ...                    ...              ...     ...
# 36922           -73.945114        40.745949      29
# 5793772         -73.943207        40.753162      29
# 5042014         -73.945404        40.745926      29
# 31688583        -73.936272        40.750038      29
# 7482863         -73.942329        40.754185      29
#
# [15000 rows x 3 columns]

# %%
# value counts

sampled_data["region"].value_counts()
# Out:
# region
# 0     500
# 1     500
# 28    500
# 27    500
# 26    500
# 25    500
# 24    500
# 23    500
# 22    500
# 21    500
# 20    500
# 19    500
# 18    500
# 17    500
# 16    500
# 15    500
# 14    500
# 13    500
# 12    500
# 11    500
# 10    500
# 9     500
# 8     500
# 7     500
# 6     500
# 5     500
# 4     500
# 3     500
# 2     500
# 29    500
# Name: count, dtype: int64

# %%
# plot the sampled data on scatterplot

fig,ax = plt.subplots(nrows=1,ncols=1,sharey=True,
                     figsize=(15,10))

ax.set_facecolor('k')
ax.set_xlim(left=-74.05, right=-73.75)

ax.scatter(sampled_data['pickup_longitude'],sampled_data['pickup_latitude'],
           s=0.05,c=sampled_data['region'],cmap="Set2")
ax.set_title('Heatmap for Pickups')
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')

plt.show()

# %%
# save the sampled data

save_path = "../data/external/plot_data.csv"

# sampled_data.to_csv(save_path, index=False)

# %%
# load the test data

data_path = "../data/processed/test.csv"

test_df = pd.read_csv(data_path, parse_dates=["tpep_pickup_datetime"]).set_index("tpep_pickup_datetime")

test_df
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-03-01 00:00:00    36.0   44.0   31.0   29.0       0             41
# 2016-03-01 00:15:00    41.0   36.0   44.0   31.0       0             35
# 2016-03-01 00:30:00    35.0   41.0   36.0   44.0       0             47
# 2016-03-01 00:45:00    47.0   35.0   41.0   36.0       0             34
# 2016-03-01 01:00:00    34.0   47.0   35.0   41.0       0             30
# ...                     ...    ...    ...    ...     ...            ...
# 2016-03-31 22:45:00    22.0   14.0   15.0   13.0      29             14
# 2016-03-31 23:00:00    14.0   22.0   14.0   15.0      29             17
# 2016-03-31 23:15:00    17.0   14.0   22.0   14.0      29             18
# 2016-03-31 23:30:00    18.0   17.0   14.0   22.0      29             13
# 2016-03-31 23:45:00    13.0   18.0   17.0   14.0      29             14
#
#                       avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-03-01 00:00:00          39.0            1
# 2016-03-01 00:15:00          37.0            1
# 2016-03-01 00:30:00          41.0            1
# 2016-03-01 00:45:00          38.0            1
# 2016-03-01 01:00:00          35.0            1
# ...                           ...          ...
# 2016-03-31 22:45:00          16.0            3
# 2016-03-31 23:00:00          16.0            3
# 2016-03-31 23:15:00          17.0            3
# 2016-03-31 23:30:00          15.0            3
# 2016-03-31 23:45:00          15.0            3
#
# [89280 rows x 8 columns]

# %%
# split the data

X_test = test_df.drop(columns=["total_pickups"])
y_test = test_df["total_pickups"]

X_test
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  avg_pickups  \
# tpep_pickup_datetime
# 2016-03-01 00:00:00    36.0   44.0   31.0   29.0       0         39.0
# 2016-03-01 00:15:00    41.0   36.0   44.0   31.0       0         37.0
# 2016-03-01 00:30:00    35.0   41.0   36.0   44.0       0         41.0
# 2016-03-01 00:45:00    47.0   35.0   41.0   36.0       0         38.0
# 2016-03-01 01:00:00    34.0   47.0   35.0   41.0       0         35.0
# ...                     ...    ...    ...    ...     ...          ...
# 2016-03-31 22:45:00    22.0   14.0   15.0   13.0      29         16.0
# 2016-03-31 23:00:00    14.0   22.0   14.0   15.0      29         16.0
# 2016-03-31 23:15:00    17.0   14.0   22.0   14.0      29         17.0
# 2016-03-31 23:30:00    18.0   17.0   14.0   22.0      29         15.0
# 2016-03-31 23:45:00    13.0   18.0   17.0   14.0      29         15.0
#
#                       day_of_week
# tpep_pickup_datetime
# 2016-03-01 00:00:00             1
# 2016-03-01 00:15:00             1
# 2016-03-01 00:30:00             1
# 2016-03-01 00:45:00             1
# 2016-03-01 01:00:00             1
# ...                           ...
# 2016-03-31 22:45:00             3
# 2016-03-31 23:00:00             3
# 2016-03-31 23:15:00             3
# 2016-03-31 23:30:00             3
# 2016-03-31 23:45:00             3
#
# [89280 rows x 7 columns]

# %%
encoder = joblib.load(encoder_path)

model = joblib.load(model_path)

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ("encoder", encoder),
    ("model",model)
])

pipe
# Out:
# Pipeline(steps=[('encoder',
#                  ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                                    remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['region', 'day_of_week'])])),
#                 ('model', LinearRegression())])

# %%
encoder
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('ohe',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['region', 'day_of_week'])])

# %%
# get the predictions

predictions = pipe.predict(X_test)

# %%
# sample row

sample_row = sampled_data.sample(1)

# %%
sample_row
# Out:
#           pickup_longitude  pickup_latitude  region
# 28521902        -73.956596        40.767139      21

# %%
# scale the coords

scaled_coords = scaler.transform(sample_row.iloc[:,0:2])

scaled_coords
# Out:
#           pickup_longitude  pickup_latitude
# 28521902          0.475219         0.590251

# %%
# calculate the distances from centroids

distances = kmeans.transform(scaled_coords).values.ravel().tolist()
# Out:
# c:\Users\himan\anaconda3\envs\demand_prediction\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but MiniBatchKMeans was fitted without feature names
#   warnings.warn(

# %%
distances = list(enumerate(distances))

distances
# Out:
# [(0, 1.3640227825550195),
#  (1, 0.9147647693329359),
#  (2, 2.763334959385068),
#  (3, 6.438908418790211),
#  (4, 2.17556400744597),
#  (5, 0.6330461373157708),
#  (6, 2.38950430574828),
#  (7, 1.4149748253434251),
#  (8, 0.48815233935736624),
#  (9, 2.946996013780299),
#  (10, 1.8183876292796326),
#  (11, 0.8121803228309538),
#  (12, 1.2375119824917566),
#  (13, 1.1479510305703575),
#  (14, 0.967252670655194),
#  (15, 0.9127921687547615),
#  (16, 1.9086613270473856),
#  (17, 2.2275164806277825),
#  (18, 0.45989714961478384),
#  (19, 0.7646780530952013),
#  (20, 2.594037643019477),
#  (21, 0.1157831099880264),
#  (22, 1.8243293468299577),
#  (23, 1.0873488855529738),
#  (24, 3.780805324345093),
#  (25, 1.0432873803557394),
#  (26, 1.3325803419993953),
#  (27, 1.5764291494117173),
#  (28, 3.2554513676509096),
#  (29, 0.9094449311287288)]

# %%
# sort the distances

indexes = [ind[0] for ind in sorted(distances, key=lambda x: x[1])][0:9]

indexes
# Out:
# [21, 18, 8, 5, 19, 11, 29, 15, 1]
